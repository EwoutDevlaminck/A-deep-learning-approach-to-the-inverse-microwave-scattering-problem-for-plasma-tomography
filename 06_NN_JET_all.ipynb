# %% [markdown]
# # Imports

# %%
pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\ewout\anaconda3\lib\site-packages (1.3.5)
# Requirement already satisfied: kt-legacy in c:\users\ewout\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: requests in c:\users\ewout\anaconda3\lib\site-packages (from keras-tuner) (2.28.1)
# Requirement already satisfied: packaging in c:\users\ewout\anaconda3\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ewout\anaconda3\lib\site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ewout\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ewout\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ewout\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ewout\anaconda3\lib\site-packages (from requests->keras-tuner) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

np.set_printoptions(precision=3, suppress=True)
from IPython.display import clear_output
plt.set_cmap('cividis')


from scipy import interpolate

#specific Neural Network imports

import tensorflow as tf
import keras
import keras_tuner
import keras.backend as K

from keras_tuner import RandomSearch, Hyperband, GridSearch, BayesianOptimization, HyperModel, Objective, Tuner, HyperParameters
from keras import layers
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.models import load_model, save_model


#imports for scikit learn, for general ML techniques


from sklearn.model_selection import StratifiedShuffleSplit, ShuffleSplit
from sklearn.decomposition import PCA

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
#Creating some colors for use throughout the notebook
cmap = matplotlib.cm.get_cmap('cividis')
colors = [cmap(i) for i in np.arange(0.1, 1.1, 0.1)]
for i, col in enumerate(colors):
  plt.scatter(i, 0, color=colors[i], s=200)

# %% [markdown]
# # Get the data

# %% [markdown]
# ## Importing and preprocess

# %%
def getData_profile(filename, outputs=[0], features_start=7):
    #read out the data from a csv file and remove n_period column

    data = pd.read_csv(filename, sep=',', header=0)

    if len(outputs)>1:
        y_df = data.iloc[:, outputs[0]:outputs[-1]+1]
    else:
        y_df = data.iloc[:, outputs[0]]
        
    X_df = data.iloc[:, features_start::]
        
    return y_df, X_df

#y_df, X_df = getData_profile('sims_custom\dens_data_subtr.csv', outputs=[0, 1, 2])
y_df_a, X_df_a = getData_profile('JET_data_noELM.csv', outputs=[0, 1, 2, 3, 4, 5, 6])
y_df_b, X_df_b = getData_profile('JET_all.csv', outputs=[0, 1, 2, 3, 4, 5, 6])

y_df = np.concatenate((y_df_a, y_df_b), axis=0)
X_df = np.concatenate((X_df_a, X_df_b), axis=0)




def add_noise(img, var):
    '''Add random noise to an image'''

    noise = np.random.normal(0, var, img.shape)
    img_noised= noise + img
    return img_noised

def preProcessing_PCA(y_df, X_df, comps=5, test_size=0.2, random_state=0, noise=True, var_noise=0.01):
    #Do all the preprocessing steps for training and validation:
    #Properly expand dimensions
    #Split and renormalize to train max
    #add gaussian noise

    X = np.expand_dims(np.array(X_df), -1) #needed for the convolutional structure
    y = np.array(y_df)


    sss = ShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)
    train_idx, test_idx = next(sss.split(X, y[:, 0]))

    x_train, y_train = X[train_idx], y[train_idx]
    x_test, y_test = X[test_idx], y[test_idx]
    
    highest_peak = np.amax(abs(x_train))
    print(highest_peak)
    print(np.amin(x_train))
    x_train /= highest_peak
    x_test  /= highest_peak
    new_max = np.amax(abs(x_train))
    print(new_max)
    #get all the data to be normalized in a sense, to have the largest absolute value of 1
    #then the standard deviation of the noise you add is 1% of this max, quite substantial!
    
    if noise:
        for i, sample in enumerate(x_train):
            x_train[i] = add_noise(sample, var_noise*new_max)
        for i, sample in enumerate(x_test):
            x_test[i] = add_noise(sample, var_noise*new_max)

    pca = PCA(n_components=comps)
    pca.fit(x_train[:, :-1, 0])

    x_pca_train = pca.transform(x_train[:, :-1, 0])
    x_pca_test = pca.transform(x_test[:, :-1, 0])

    return x_train, x_pca_train, x_test, x_pca_test, y_train, y_test, pca


n_PCA_comps = 20

x_train, x_pca_train, x_test, x_pca_test, y_train, y_test, pca_model = preProcessing_PCA(y_df, X_df, comps=n_PCA_comps, noise=True, var_noise=0.01)


x_train_1, x_pca_train_1, x_test_1, x_pca_test_1, y_train_1, y_test_1, pca_model_1 = preProcessing_PCA(y_df, X_df, comps=n_PCA_comps, noise=False, var_noise=0.01)
# Out:
# 46.78662
# 0.00011
# 1.0
# 46.78662
# 0.00011
# 1.0

# %%
x_train.shape
# Out:
# (8640, 546, 1)

# %%
fig, ax = plt.subplots()

ax.hlines(0, xmin=0, xmax=x_train.shape[1], color='black', linewidth=1)
ax.plot(x_train[800, :, 0], c=colors[0], label='noisy')
ax.plot(x_train_1[800, :, 0]-.1, c='orange', label='clean + offset')
ax.legend(loc='upper left', fontsize=13)

ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_title('Examples of input data', fontsize=16)
ax.set_ylabel(r'Intensity (AU)', fontsize=14)
ax.set_xlabel(r'Measurement channel', fontsize=14)

plt.xlim(0, x_train.shape[1])
# Out:
# (0.0, 546.0)

# %% [markdown]
# ## Exploring the PCA analysis for this case

# %%
plt.scatter(x_pca_train[:, 0], x_pca_train[:, 1], s=1)

# %%
plt.plot(np.cumsum(pca_model.explained_variance_ratio_), c=colors[0])
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
plt.ylim(.9, 1)
plt.axhline(0.996, c='black')
plt.axvline(20, c='black')

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 5))

ax[0, 0].plot(pca_model.components_[0], linewidth=1, label='1', c=colors[0])
ax[0, 1].plot(pca_model.components_[1], linewidth=1, label='2', c=colors[0])
ax[1, 0].plot(pca_model.components_[2], linewidth=1, label='3', c=colors[0])
ax[1, 1].plot(pca_model.components_[3], linewidth=1, label='4', c=colors[0])

# %%
plt.plot(x_train[800, :, 0])

plt.plot(pca_model.inverse_transform(x_pca_train[800]))
plt.xlim(0, x_train.shape[1])
plt.ylim(0)
# Out:
# (0.0, 0.48420369567100774)

# %% [markdown]
# ## The JET profiles

# %%
from scipy.optimize import root_scalar
from mpl_toolkits.axes_grid1 import make_axes_locatable

def jet(angle, a, R0, delta, kappa):
    R = R0 + a*np.cos(angle + delta*np.sin(angle))
    z = kappa*a*np.sin(angle)

    return R, z

def inverse(R, z, R0, delta, kappa):
    
    def f(x, R=1, z=1, R0=1, delta=1, kappa=1, neg_side=False):
        theta = np.arcsin(z/(kappa*x))
        if neg_side:
            theta = np.pi - theta

        return x*np.cos(theta + delta*z/(kappa*x)) -R +R0

    try:
        a = root_scalar(f, args=(R, z, R0, delta, kappa), bracket=[abs(z/kappa)+1e-13, 2], method='brentq').root
        #The extra 1e-13 is to avoid the root finding algorithm to get stuck, as arcsin needs an argument between -1 and 1
        return a, np.arcsin(z/(kappa*a))
    
    except ValueError:
        try:
            #print('Were on the negative side')
            a = root_scalar(f, args=(R, z, R0, delta, kappa, True), bracket=[abs(z/kappa)+1e-13, 2], method='brentq').root
            return a, np.pi - np.arcsin(z/(kappa*a))
    
        except ValueError:
            return 2, np.pi

def jet_profile(a, theta, amplitude=.25, mode_num=4, phase=0.):
    if a>1:
        #This is to avoid the plasma extending beyond the last closed flux surface
        return 0 
    
    elif a< .8:
        #Inside, the density follows the flux surfaces to 1st order
        return np.sqrt(1-a) 
    
    else:
        #between around a=.8 to a=1, we add a perturbation, gaussian in a, sinusoidal in theta
        argument = (mode_num*theta + phase/mode_num if mode_num!=0 else 0)
        return np.sqrt(1-a) + amplitude * np.cos(argument)* np.exp(-((a-.9)/.04)**2) 
    

def make_density(R, z, ne_peak, R0, delta, kappa, amplitude=.0, mode_num=4, phase=0., profile=jet_profile):

    grid = np.zeros((len(z), len(R)))
    outer_contour_R, outer_contour_z = jet(np.linspace(0, 2*np.pi, 200), 1, R0, delta, kappa)
    RM, Rm, zM, zm = np.amax(outer_contour_R), np.amin(outer_contour_R), np.amax(outer_contour_z), np.amin(outer_contour_z)

    

    for i, R_val in enumerate(R):
        for j, z_val in enumerate(z):
            if R_val > RM or R_val < Rm or z_val > zM or z_val < zm:
                continue
            else:
                contour_value, theta = inverse(R_val, z_val, R0, delta, kappa)
                grid[j, i] = ne_peak *profile(contour_value, theta, amplitude, mode_num, phase)
                # use grid[i, j] to rotate and send from HFS
                # use grid[-i, j] to rotate and send from LFS


    return grid


def mirror(profile):
    return np.concatenate((profile[::-1, :], profile), axis=0)

def plot_JET(profile):

    R = np.linspace(1.6, 4.4, 40)
    z = np.linspace(0, 1.7, 40)
    z2 = np.linspace(-1.7, 1.7, 80)

    X2, Z2 = np.meshgrid(R, z2)

    full = mirror(profile)
    fig, ax = plt.subplots(figsize=(5, 5))

    ax.contourf(X2, Z2, full, levels=200, cmap='cividis')
    ax.contour(X2, Z2, full, levels=8, colors='black', linewidths=1)
    ax.contour(X2, Z2, full, levels=[0], colors='white', linewidths=1)
    ax.set_aspect('equal')
    return

# %%
q=8

# %%
ne_peak= y_train[q, 0]
R0 = y_train[q, 1]
delta = y_train[q, 2]
kappa = y_train[q, 3]
amplitude = y_train[q, 4]
mode_num = y_train[q, 5]
phase = y_train[q, 6]

R = np.linspace(1.6, 4.4, 40)
z = np.linspace(0, 1.7, 40)
z2 = np.linspace(-1.7, 1.7, 80)

X2, Z2 = np.meshgrid(R, z2)


JET_example = make_density(R,z, ne_peak, R0, delta, kappa, amplitude, mode_num, phase, jet_profile)

JET_full = mirror(JET_example)
fig, ax = plt.subplots(1, 2, figsize=(13, 5))
cont = ax[0].contourf(X2, Z2, JET_full, levels=200, cmap='cividis')
#cont = ax[0].imshow(JET_full, cmap='cividis')
ax[0].set_aspect('equal')
ax[0].set_title(f'Density profile, R0={R0}, delta={delta}, kappa={kappa}')
divider_1 = make_axes_locatable(ax[0])
cax = divider_1.append_axes("right", size="5%", pad=0.3)

contours = True
if contours:
    ax[0].contour(X2, Z2,JET_full, levels=8, colors='black', linewidths=1)
    ax[0].contour(X2, Z2,JET_full, levels=[0], colors='white', linewidths=1)

plt.colorbar(cont, cax=cax)


a_vals= np.linspace(0, 1, 300)
thetas = np.linspace(0, 2*np.pi, 10)
prof = np.array([[ne_peak*jet_profile(a, theta, amplitude, mode_num, phase) for a in a_vals] for theta in thetas])
for i in range(len(thetas)):
    ax[1].plot(a_vals, prof[i], linewidth=1, label=f'theta={(thetas[i]/np.pi*180):.2f}°')
ax[1].set_xlabel('a')
ax[1].set_ylabel('Density')
ax[1].set_title('Density in terms of a')
ax[1].legend()
# Out:
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\2474018900.py:30: UserWarning: No contour levels were found within the data range.
#   ax[0].contour(X2, Z2,JET_full, levels=[0], colors='white', linewidths=1)

# %% [markdown]
# ## Generating the resolved training data

# %%
"""Making new training and testing data, by now having the output as the resolved images"""

y_train_new = np.array([make_density(R, z, train_sample[0], train_sample[1], train_sample[2], train_sample[3], train_sample[4], train_sample[5], train_sample[6])
 for _, train_sample in enumerate(y_train)])
y_test_new = np.array([make_density(R, z, test_sample[0], test_sample[1], test_sample[2], test_sample[3], test_sample[4], test_sample[5], test_sample[6])
 for _, test_sample in enumerate(y_test)])

y_test_new.shape
# Out:
# (2160, 40, 40)

# %%
index = 8

plot_JET(y_train_new[index])
# Out:
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\3204209475.py:86: UserWarning: No contour levels were found within the data range.
#   ax.contour(X2, Z2, full, levels=[0], colors='white', linewidths=1)

# %% [markdown]
# ## The loss functions

# %%
def mse(y_true, y_pred):
    # Define the custom loss function here
    mse = K.mean(K.square(y_true - y_pred))

    return mse 

def rmse(y_true, y_pred):
    # Define the custom loss function here
    mse = K.mean(K.square(y_true - y_pred))
    rmse = K.sqrt(mse)

    return rmse

def nrmse(y_true, y_pred):
    # Define the custom loss function here
    mse = K.mean(K.square(y_true - y_pred))
    rmse = K.sqrt(mse)
    min_val = K.min(y_true)
    max_val = K.max(y_true)
    return rmse / (max_val - min_val)

def SSIMLoss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

# For evaluation

from skimage.metrics import structural_similarity as ssim

#non-differentiable, don't use for training!

def ssim_loss(y_true, y_pred):
    # Define the custom loss function here
    return  ssim(y_true, y_pred, multichannel=True)

def psnr(y_true, y_pred):
    max_pixel = K.max(y_true)
    return 20 * K.log(max_pixel / K.sqrt(K.mean(K.square(y_true - y_pred)))) / K.log(10.0)

def mae(y_true, y_pred):
    return K.mean(K.abs(y_true - y_pred))


def loss_split(y_true, y_pred, frac=0.5):
    return frac*SSIMLoss(y_true, y_pred) + (1-frac)*nrmse(y_true, y_pred)

# %% [markdown]
# # Model generation

# %%
x_train.shape
# Out:
# (8640, 546, 1)

# %%
def create_JET_model(hp):
    model = tf.keras.models.Sequential()

    model.add(layers.AveragePooling1D(pool_size=5, strides=2, padding='same', name='pool1'))

    for i in range(hp.Int("num__conv_layers", 2, 3, default=3)):

        kernelsize = int(np.max([3, (2**(4-i)-1)]))
        model.add(layers.Conv1D(np.min([8*(2**i), 32]), kernel_size=kernelsize, padding='same', name=f'conv{i+1}'))
        model.add(layers.LeakyReLU())
        model.add(layers.BatchNormalization())
        model.add(layers.MaxPooling1D(pool_size=2, strides=2,padding='same', name=f'pool{i+2}'))

    model.add(layers.Flatten(name='flatten'))

    rate = hp.Choice(f'droprate', [.1, .15, .2, .25], default=.15)
    for i in range(hp.Int("num__dens_layers", 1, 2, default=2)):
        if hp.Boolean("dropout", default=True):
            model.add(keras.layers.Dropout(rate=rate, name=f'drop{i+1}'))
        model.add(layers.Dense(units=hp.Int(f"units_{i+1}", min_value=500, max_value=1500, step=250, default=1250)
                                        , activation='relu', name=f'dens{i+1}'))

    model.add(layers.Reshape((5, 5, -1)))

    model.add(layers.Conv2DTranspose(8, (3, 3), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.LeakyReLU())
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
   
    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))

    model.add(layers.Conv2D(1, (5, 5), strides=(1, 1), padding='same', use_bias=False, activation='relu'))
    """
    lr_schedule = schedules.ExponentialDecay(
                    initial_learning_rate=1e-2,
                    decay_steps=50,
                    decay_rate=0.9)
    """
    optimizer = getattr(tf.keras.optimizers, "Adam")(learning_rate=hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log", default=0.0005))
    loss_func = hp.Choice("loss_func", ["nrmse", "ssim", "loss_split"], default="loss_split")
    if loss_func == "nrmse":
        model.compile(optimizer=optimizer, loss=nrmse)
    elif loss_func == "ssim":
        model.compile(optimizer=optimizer, loss=SSIMLoss)
    elif loss_func == "loss_split":
        model.compile(optimizer=optimizer, loss=loss_split)

    return model

# %% [markdown]
# # Tuning hyperparameters

# %% [markdown]
# # Retraining ideal model

# %%
hp_split = keras_tuner.HyperParameters()


hp_split.Int(f"units_{2}", min_value=1500, max_value=1500, step=250)
# Out:
# 1500

# %%
hp_nrmse = keras_tuner.HyperParameters()


hp_nrmse.Int(f"units_{2}", min_value=1500, max_value=1500, step=250)
hp_nrmse.Choice(f"loss_func", values=['nrmse'])
# Out:
# 'nrmse'

# %%
hp_ssim = keras_tuner.HyperParameters()


hp_ssim.Int(f"units_{2}", min_value=1500, max_value=1500, step=250)
hp_ssim.Choice(f"loss_func", values=['ssim'])
# Out:
# 'ssim'

# %%
model_split = create_JET_model(hp_split)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=40)
mc_full = ModelCheckpoint('06_files/tuning/optimised_model.h5', monitor='val_loss', mode='min', verbose=0, save_best_only=True)

history_split = model_split.fit(x_train, y_train_new, validation_split=0.2, epochs=400, batch_size=64, verbose=1, callbacks=[es, mc_full])
# Out:
# Epoch 1/400
# 108/108 [==============================] - 9s 66ms/step - loss: 0.1915 - val_loss: 0.3764
# Epoch 2/400
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0954 - val_loss: 0.3071
# Epoch 3/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0772 - val_loss: 0.2798
# Epoch 4/400
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0691 - val_loss: 0.2407
# Epoch 5/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0647 - val_loss: 0.2118
# Epoch 6/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0589 - val_loss: 0.1572
# Epoch 7/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0574 - val_loss: 0.1071
# Epoch 8/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0543 - val_loss: 0.0522
# Epoch 9/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0520 - val_loss: 0.0534
# Epoch 10/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0503 - val_loss: 0.0567
# Epoch 11/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0489 - val_loss: 0.0514
# Epoch 12/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0477 - val_loss: 0.0476
# Epoch 13/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0462 - val_loss: 0.0770
# Epoch 14/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0459 - val_loss: 0.0472
# Epoch 15/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0453 - val_loss: 0.0419
# Epoch 16/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0433 - val_loss: 0.0579
# Epoch 17/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0433 - val_loss: 0.0445
# Epoch 18/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0430 - val_loss: 0.0434
# Epoch 19/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0419 - val_loss: 0.0444
# Epoch 20/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0415 - val_loss: 0.0585
# Epoch 21/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0405 - val_loss: 0.0435
# Epoch 22/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0403 - val_loss: 0.0418
# Epoch 23/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0393 - val_loss: 0.0527
# Epoch 24/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0390 - val_loss: 0.0423
# Epoch 25/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0378 - val_loss: 0.0457
# Epoch 26/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0378 - val_loss: 0.0427
# Epoch 27/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0376 - val_loss: 0.0403
# Epoch 28/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0377 - val_loss: 0.0448
# Epoch 29/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0369 - val_loss: 0.0428
# Epoch 30/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0365 - val_loss: 0.0668
# Epoch 31/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0357 - val_loss: 0.0431
# Epoch 32/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0351 - val_loss: 0.0479
# Epoch 33/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0353 - val_loss: 0.0436
# Epoch 34/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0353 - val_loss: 0.0404
# Epoch 35/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0345 - val_loss: 0.0507
# Epoch 36/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0343 - val_loss: 0.0454
# Epoch 37/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0337 - val_loss: 0.0392
# Epoch 38/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0337 - val_loss: 0.0393
# Epoch 39/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0332 - val_loss: 0.0420
# Epoch 40/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0331 - val_loss: 0.0496
# Epoch 41/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0320 - val_loss: 0.0376
# Epoch 42/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0317 - val_loss: 0.0397
# Epoch 43/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0320 - val_loss: 0.0433
# Epoch 44/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0318 - val_loss: 0.0377
# Epoch 45/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0311 - val_loss: 0.0373
# Epoch 46/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0314 - val_loss: 0.0489
# Epoch 47/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0307 - val_loss: 0.0390
# Epoch 48/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0313 - val_loss: 0.0427
# Epoch 49/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0305 - val_loss: 0.0373
# Epoch 50/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0301 - val_loss: 0.0370
# Epoch 51/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0309 - val_loss: 0.0393
# Epoch 52/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0296 - val_loss: 0.0389
# Epoch 53/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0295 - val_loss: 0.0397
# Epoch 54/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0293 - val_loss: 0.0452
# Epoch 55/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0291 - val_loss: 0.0400
# Epoch 56/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0289 - val_loss: 0.0382
# Epoch 57/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0283 - val_loss: 0.0398
# Epoch 58/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0281 - val_loss: 0.0420
# Epoch 59/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0280 - val_loss: 0.0370
# Epoch 60/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0273 - val_loss: 0.0577
# Epoch 61/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0281 - val_loss: 0.0397
# Epoch 62/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0274 - val_loss: 0.0364
# Epoch 63/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0283 - val_loss: 0.0368
# Epoch 64/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0264 - val_loss: 0.0363
# Epoch 65/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0262 - val_loss: 0.0396
# Epoch 66/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0266 - val_loss: 0.0373
# Epoch 67/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0262 - val_loss: 0.0366
# Epoch 68/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0264 - val_loss: 0.0448
# Epoch 69/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0258 - val_loss: 0.0446
# Epoch 70/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0263 - val_loss: 0.0371
# Epoch 71/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0257 - val_loss: 0.0577
# Epoch 72/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0258 - val_loss: 0.0469
# Epoch 73/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0263 - val_loss: 0.0375
# Epoch 74/400
# 108/108 [==============================] - 7s 67ms/step - loss: 0.0249 - val_loss: 0.0397
# Epoch 75/400
# 108/108 [==============================] - 7s 64ms/step - loss: 0.0251 - val_loss: 0.0373
# Epoch 76/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0252 - val_loss: 0.0384
# Epoch 77/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0246 - val_loss: 0.0441
# Epoch 78/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0244 - val_loss: 0.0373
# Epoch 79/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0246 - val_loss: 0.0427
# Epoch 80/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0241 - val_loss: 0.0381
# Epoch 81/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0242 - val_loss: 0.0373
# Epoch 82/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0236 - val_loss: 0.0376
# Epoch 83/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0238 - val_loss: 0.0385
# Epoch 84/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0238 - val_loss: 0.0534
# Epoch 85/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0246 - val_loss: 0.0453
# Epoch 86/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0234 - val_loss: 0.0430
# Epoch 87/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0232 - val_loss: 0.0377
# Epoch 88/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0232 - val_loss: 0.0351
# Epoch 89/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0229 - val_loss: 0.0366
# Epoch 90/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0228 - val_loss: 0.0363
# Epoch 91/400
# 108/108 [==============================] - 7s 69ms/step - loss: 0.0225 - val_loss: 0.0385
# Epoch 92/400
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0230 - val_loss: 0.0465
# Epoch 93/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0227 - val_loss: 0.0412
# Epoch 94/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0223 - val_loss: 0.0358
# Epoch 95/400
# 108/108 [==============================] - 7s 60ms/step - loss: 0.0229 - val_loss: 0.0458
# Epoch 96/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0219 - val_loss: 0.0411
# Epoch 97/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0224 - val_loss: 0.0444
# Epoch 98/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0219 - val_loss: 0.0413
# Epoch 99/400
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0220 - val_loss: 0.0410
# Epoch 100/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0220 - val_loss: 0.0435
# Epoch 101/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0218 - val_loss: 0.0386
# Epoch 102/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0218 - val_loss: 0.0448
# Epoch 103/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0213 - val_loss: 0.0380
# Epoch 104/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0211 - val_loss: 0.0427
# Epoch 105/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0213 - val_loss: 0.0464
# Epoch 106/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0208 - val_loss: 0.0403
# Epoch 107/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0210 - val_loss: 0.0386
# Epoch 108/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0209 - val_loss: 0.0405
# Epoch 109/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0209 - val_loss: 0.0370
# Epoch 110/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0207 - val_loss: 0.0366
# Epoch 111/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0204 - val_loss: 0.0382
# Epoch 112/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0209 - val_loss: 0.0368
# Epoch 113/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0208 - val_loss: 0.0429
# Epoch 114/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0206 - val_loss: 0.0382
# Epoch 115/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0200 - val_loss: 0.0385
# Epoch 116/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0201 - val_loss: 0.0379
# Epoch 117/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0199 - val_loss: 0.0384
# Epoch 118/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0200 - val_loss: 0.0367
# Epoch 119/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0195 - val_loss: 0.0407
# Epoch 120/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0204 - val_loss: 0.0401
# Epoch 121/400
# 108/108 [==============================] - 7s 66ms/step - loss: 0.0199 - val_loss: 0.0456
# Epoch 122/400
# 108/108 [==============================] - 8s 71ms/step - loss: 0.0197 - val_loss: 0.0371
# Epoch 123/400
# 108/108 [==============================] - 7s 65ms/step - loss: 0.0194 - val_loss: 0.0391
# Epoch 124/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0194 - val_loss: 0.0385
# Epoch 125/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0193 - val_loss: 0.0373
# Epoch 126/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0193 - val_loss: 0.0393
# Epoch 127/400
# 108/108 [==============================] - 7s 63ms/step - loss: 0.0190 - val_loss: 0.0377
# Epoch 128/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0191 - val_loss: 0.0399
# Epoch 128: early stopping

# %%
model_nrmse = create_JET_model(hp_nrmse)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=40)
mc_full = ModelCheckpoint('06_files/tuning/nrmse_model.h5', monitor='val_loss', mode='min', verbose=0, save_best_only=True)

history_nrmse = model_nrmse.fit(x_train, y_train_new, validation_split=0.2, epochs=400, batch_size=64, verbose=1, callbacks=[es, mc_full])
# Out:
# Epoch 1/400
# 108/108 [==============================] - 7s 52ms/step - loss: 0.1719 - val_loss: 0.1840
# Epoch 2/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0794 - val_loss: 0.1235
# Epoch 3/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0449 - val_loss: 0.1198
# Epoch 4/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0406 - val_loss: 0.1227
# Epoch 5/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0381 - val_loss: 0.0900
# Epoch 6/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0355 - val_loss: 0.0649
# Epoch 7/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0345 - val_loss: 0.0346
# Epoch 8/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0333 - val_loss: 0.0558
# Epoch 9/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0322 - val_loss: 0.0311
# Epoch 10/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0313 - val_loss: 0.0425
# Epoch 11/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0311 - val_loss: 0.0337
# Epoch 12/400
# 108/108 [==============================] - 6s 51ms/step - loss: 0.0308 - val_loss: 0.0331
# Epoch 13/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0296 - val_loss: 0.0329
# Epoch 14/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0290 - val_loss: 0.0319
# Epoch 15/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0289 - val_loss: 0.0310
# Epoch 16/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0283 - val_loss: 0.0377
# Epoch 17/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0280 - val_loss: 0.0306
# Epoch 18/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0276 - val_loss: 0.0292
# Epoch 19/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0273 - val_loss: 0.0270
# Epoch 20/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0272 - val_loss: 0.0279
# Epoch 21/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0270 - val_loss: 0.0275
# Epoch 22/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0266 - val_loss: 0.0304
# Epoch 23/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0262 - val_loss: 0.0286
# Epoch 24/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0260 - val_loss: 0.0297
# Epoch 25/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0260 - val_loss: 0.0321
# Epoch 26/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0257 - val_loss: 0.0281
# Epoch 27/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0257 - val_loss: 0.0355
# Epoch 28/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0250 - val_loss: 0.0298
# Epoch 29/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0251 - val_loss: 0.0270
# Epoch 30/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0246 - val_loss: 0.0261
# Epoch 31/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0246 - val_loss: 0.0267
# Epoch 32/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0245 - val_loss: 0.0260
# Epoch 33/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0240 - val_loss: 0.0300
# Epoch 34/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0240 - val_loss: 0.0257
# Epoch 35/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0239 - val_loss: 0.0361
# Epoch 36/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0238 - val_loss: 0.0269
# Epoch 37/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0235 - val_loss: 0.0258
# Epoch 38/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0233 - val_loss: 0.0295
# Epoch 39/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0233 - val_loss: 0.0261
# Epoch 40/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0229 - val_loss: 0.0254
# Epoch 41/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0231 - val_loss: 0.0312
# Epoch 42/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0232 - val_loss: 0.0257
# Epoch 43/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0227 - val_loss: 0.0249
# Epoch 44/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0227 - val_loss: 0.0251
# Epoch 45/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0225 - val_loss: 0.0265
# Epoch 46/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0224 - val_loss: 0.0310
# Epoch 47/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0223 - val_loss: 0.0272
# Epoch 48/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0218 - val_loss: 0.0252
# Epoch 49/400
# 108/108 [==============================] - 6s 53ms/step - loss: 0.0219 - val_loss: 0.0250
# Epoch 50/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0218 - val_loss: 0.0260
# Epoch 51/400
# 108/108 [==============================] - 6s 53ms/step - loss: 0.0216 - val_loss: 0.0247
# Epoch 52/400
# 108/108 [==============================] - 6s 53ms/step - loss: 0.0218 - val_loss: 0.0312
# Epoch 53/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0219 - val_loss: 0.0264
# Epoch 54/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0215 - val_loss: 0.0252
# Epoch 55/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0214 - val_loss: 0.0257
# Epoch 56/400
# 108/108 [==============================] - 6s 51ms/step - loss: 0.0212 - val_loss: 0.0255
# Epoch 57/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0214 - val_loss: 0.0250
# Epoch 58/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0208 - val_loss: 0.0246
# Epoch 59/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0209 - val_loss: 0.0263
# Epoch 60/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0206 - val_loss: 0.0244
# Epoch 61/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0209 - val_loss: 0.0267
# Epoch 62/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0207 - val_loss: 0.0243
# Epoch 63/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0206 - val_loss: 0.0248
# Epoch 64/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0206 - val_loss: 0.0331
# Epoch 65/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0204 - val_loss: 0.0256
# Epoch 66/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0203 - val_loss: 0.0248
# Epoch 67/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0203 - val_loss: 0.0258
# Epoch 68/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0202 - val_loss: 0.0249
# Epoch 69/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0201 - val_loss: 0.0250
# Epoch 70/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0201 - val_loss: 0.0244
# Epoch 71/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0197 - val_loss: 0.0246
# Epoch 72/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0199 - val_loss: 0.0246
# Epoch 73/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0198 - val_loss: 0.0262
# Epoch 74/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0197 - val_loss: 0.0302
# Epoch 75/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0197 - val_loss: 0.0253
# Epoch 76/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0194 - val_loss: 0.0280
# Epoch 77/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0193 - val_loss: 0.0249
# Epoch 78/400
# 108/108 [==============================] - 6s 54ms/step - loss: 0.0195 - val_loss: 0.0243
# Epoch 79/400
# 108/108 [==============================] - 6s 60ms/step - loss: 0.0193 - val_loss: 0.0272
# Epoch 80/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0193 - val_loss: 0.0253
# Epoch 81/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0192 - val_loss: 0.0258
# Epoch 82/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0192 - val_loss: 0.0258
# Epoch 83/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0188 - val_loss: 0.0245
# Epoch 84/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0188 - val_loss: 0.0287
# Epoch 85/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0187 - val_loss: 0.0288
# Epoch 86/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0189 - val_loss: 0.0271
# Epoch 87/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0188 - val_loss: 0.0270
# Epoch 88/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0189 - val_loss: 0.0251
# Epoch 89/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0187 - val_loss: 0.0248
# Epoch 90/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0186 - val_loss: 0.0270
# Epoch 91/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0183 - val_loss: 0.0261
# Epoch 92/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0182 - val_loss: 0.0253
# Epoch 93/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0184 - val_loss: 0.0252
# Epoch 94/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0183 - val_loss: 0.0250
# Epoch 95/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0183 - val_loss: 0.0254
# Epoch 96/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0181 - val_loss: 0.0252
# Epoch 97/400
# 108/108 [==============================] - 5s 45ms/step - loss: 0.0183 - val_loss: 0.0248
# Epoch 98/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0183 - val_loss: 0.0314
# Epoch 99/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0180 - val_loss: 0.0251
# Epoch 100/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0181 - val_loss: 0.0265
# Epoch 101/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0182 - val_loss: 0.0249
# Epoch 102/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0179 - val_loss: 0.0246
# Epoch 103/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0177 - val_loss: 0.0256
# Epoch 104/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0175 - val_loss: 0.0263
# Epoch 105/400
# 108/108 [==============================] - 5s 46ms/step - loss: 0.0176 - val_loss: 0.0251
# Epoch 106/400
# 108/108 [==============================] - 5s 48ms/step - loss: 0.0175 - val_loss: 0.0244
# Epoch 107/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0177 - val_loss: 0.0266
# Epoch 108/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0175 - val_loss: 0.0255
# Epoch 109/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0176 - val_loss: 0.0244
# Epoch 110/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0176 - val_loss: 0.0257
# Epoch 111/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0175 - val_loss: 0.0265
# Epoch 112/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0176 - val_loss: 0.0246
# Epoch 113/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0173 - val_loss: 0.0253
# Epoch 114/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0174 - val_loss: 0.0278
# Epoch 115/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0173 - val_loss: 0.0245
# Epoch 116/400
# 108/108 [==============================] - 5s 47ms/step - loss: 0.0173 - val_loss: 0.0250
# Epoch 117/400
# 108/108 [==============================] - 5s 50ms/step - loss: 0.0171 - val_loss: 0.0252
# Epoch 118/400
# 108/108 [==============================] - 5s 49ms/step - loss: 0.0172 - val_loss: 0.0274
# Epoch 118: early stopping

# %%
model_ssim = create_JET_model(hp_ssim)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=40)
mc_full = ModelCheckpoint('06_files/tuning/ssim_model.h5', monitor='val_loss', mode='min', verbose=0, save_best_only=True)

history_ssim = model_split.fit(x_train, y_train_new, validation_split=0.2, epochs=400, batch_size=64, verbose=1, callbacks=[es, mc_full])
# Out:
# Epoch 1/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0193 - val_loss: 0.0378
# Epoch 2/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0191 - val_loss: 0.0367
# Epoch 3/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0196 - val_loss: 0.0392
# Epoch 4/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0191 - val_loss: 0.0371
# Epoch 5/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0191 - val_loss: 0.0398
# Epoch 6/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0189 - val_loss: 0.0382
# Epoch 7/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0187 - val_loss: 0.0370
# Epoch 8/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0189 - val_loss: 0.0370
# Epoch 9/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0185 - val_loss: 0.0371
# Epoch 10/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0186 - val_loss: 0.0388
# Epoch 11/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0183 - val_loss: 0.0428
# Epoch 12/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0188 - val_loss: 0.0375
# Epoch 13/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0183 - val_loss: 0.0413
# Epoch 14/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0185 - val_loss: 0.0445
# Epoch 15/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0183 - val_loss: 0.0379
# Epoch 16/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0183 - val_loss: 0.0389
# Epoch 17/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0179 - val_loss: 0.0377
# Epoch 18/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0181 - val_loss: 0.0402
# Epoch 19/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0185 - val_loss: 0.0380
# Epoch 20/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0181 - val_loss: 0.0391
# Epoch 21/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0183 - val_loss: 0.0385
# Epoch 22/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0181 - val_loss: 0.0381
# Epoch 23/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0178 - val_loss: 0.0376
# Epoch 24/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0177 - val_loss: 0.0390
# Epoch 25/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0176 - val_loss: 0.0381
# Epoch 26/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0177 - val_loss: 0.0394
# Epoch 27/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0174 - val_loss: 0.0387
# Epoch 28/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0174 - val_loss: 0.0372
# Epoch 29/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0174 - val_loss: 0.0373
# Epoch 30/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0172 - val_loss: 0.0401
# Epoch 31/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0174 - val_loss: 0.0392
# Epoch 32/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0171 - val_loss: 0.0392
# Epoch 33/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0170 - val_loss: 0.0375
# Epoch 34/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0171 - val_loss: 0.0452
# Epoch 35/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0175 - val_loss: 0.0412
# Epoch 36/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0174 - val_loss: 0.0373
# Epoch 37/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0170 - val_loss: 0.0382
# Epoch 38/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0171 - val_loss: 0.0383
# Epoch 39/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0170 - val_loss: 0.0395
# Epoch 40/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0172 - val_loss: 0.0405
# Epoch 41/400
# 108/108 [==============================] - 6s 55ms/step - loss: 0.0170 - val_loss: 0.0413
# Epoch 42/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0169 - val_loss: 0.0364
# Epoch 43/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0170 - val_loss: 0.0389
# Epoch 44/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0169 - val_loss: 0.0370
# Epoch 45/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0168 - val_loss: 0.0374
# Epoch 46/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0168 - val_loss: 0.0398
# Epoch 47/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0167 - val_loss: 0.0383
# Epoch 48/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0165 - val_loss: 0.0400
# Epoch 49/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0167 - val_loss: 0.0400
# Epoch 50/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0168 - val_loss: 0.0381
# Epoch 51/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0165 - val_loss: 0.0373
# Epoch 52/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0165 - val_loss: 0.0382
# Epoch 53/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0165 - val_loss: 0.0413
# Epoch 54/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0164 - val_loss: 0.0374
# Epoch 55/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0161 - val_loss: 0.0400
# Epoch 56/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0162 - val_loss: 0.0385
# Epoch 57/400
# 108/108 [==============================] - 7s 62ms/step - loss: 0.0163 - val_loss: 0.0384
# Epoch 58/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0164 - val_loss: 0.0384
# Epoch 59/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0160 - val_loss: 0.0372
# Epoch 60/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0167 - val_loss: 0.0441
# Epoch 61/400
# 108/108 [==============================] - 6s 56ms/step - loss: 0.0165 - val_loss: 0.0377
# Epoch 62/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0162 - val_loss: 0.0400
# Epoch 63/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0161 - val_loss: 0.0395
# Epoch 64/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0162 - val_loss: 0.0377
# Epoch 65/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0165 - val_loss: 0.0379
# Epoch 66/400
# 108/108 [==============================] - 7s 61ms/step - loss: 0.0161 - val_loss: 0.0412
# Epoch 67/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0158 - val_loss: 0.0483
# Epoch 68/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0162 - val_loss: 0.0370
# Epoch 69/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0159 - val_loss: 0.0417
# Epoch 70/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0158 - val_loss: 0.0375
# Epoch 71/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0157 - val_loss: 0.0384
# Epoch 72/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0159 - val_loss: 0.0385
# Epoch 73/400
# 108/108 [==============================] - 6s 58ms/step - loss: 0.0158 - val_loss: 0.0373
# Epoch 74/400
# 108/108 [==============================] - 6s 59ms/step - loss: 0.0158 - val_loss: 0.0379
# Epoch 75/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0158 - val_loss: 0.0370
# Epoch 76/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0157 - val_loss: 0.0372
# Epoch 77/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0155 - val_loss: 0.0392
# Epoch 78/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0156 - val_loss: 0.0381
# Epoch 79/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0156 - val_loss: 0.0383
# Epoch 80/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0157 - val_loss: 0.0408
# Epoch 81/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0157 - val_loss: 0.0383
# Epoch 82/400
# 108/108 [==============================] - 6s 57ms/step - loss: 0.0155 - val_loss: 0.0392
# Epoch 82: early stopping

# %%
optimised_result = model_split
ssim_result = model_ssim
nrmse_result = model_nrmse
"""
optimised_result = load_model("06_files/tuning/optimised_model.h5", custom_objects={'loss_split': loss_split, 'nrmse': nrmse, 'SSIMLoss': SSIMLoss, 'ssim': ssim, 'psnr': psnr, 'mae': mae})
ssim_result = load_model("06_files/tuning/ssim_model.h5", custom_objects={'loss_split': loss_split, 'nrmse': nrmse, 'SSIMLoss': SSIMLoss, 'ssim': ssim, 'psnr': psnr, 'mae': mae})
nrmse_result = load_model("06_files/tuning/nrmse_model.h5", custom_objects={'loss_split': loss_split, 'nrmse': nrmse, 'SSIMLoss': SSIMLoss, 'ssim': ssim, 'psnr': psnr, 'mae': mae})
"""
# Out:
# '\noptimised_result = load_model("06_files/tuning/optimised_model.h5", custom_objects={\'loss_split\': loss_split, \'nrmse\': nrmse, \'SSIMLoss\': SSIMLoss, \'ssim\': ssim, \'psnr\': psnr, \'mae\': mae})\nssim_result = load_model("06_files/tuning/ssim_model.h5", custom_objects={\'loss_split\': loss_split, \'nrmse\': nrmse, \'SSIMLoss\': SSIMLoss, \'ssim\': ssim, \'psnr\': psnr, \'mae\': mae})\nnrmse_result = load_model("06_files/tuning/nrmse_model.h5", custom_objects={\'loss_split\': loss_split, \'nrmse\': nrmse, \'SSIMLoss\': SSIMLoss, \'ssim\': ssim, \'psnr\': psnr, \'mae\': mae})\n'

# %%
plt.plot(history_split.history['loss'], label='train')
plt.plot(history_split.history['val_loss'], label='validation')

#plt.yscale('log')
plt.legend()
plt.ylim(0, .1)
#plt.axhline(0.03, c='black')
plt.show()

# %%
optimised_result.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pool1 (AveragePooling1D)    (64, 273, 1)              0
#
#  conv1 (Conv1D)              (64, 273, 8)              128
#
#  leaky_re_lu_4 (LeakyReLU)   (64, 273, 8)              0
#
#  batch_normalization_4 (Batc  (64, 273, 8)             32
#  hNormalization)
#
#  pool2 (MaxPooling1D)        (64, 137, 8)              0
#
#  conv2 (Conv1D)              (64, 137, 16)             912
#
#  leaky_re_lu_5 (LeakyReLU)   (64, 137, 16)             0
#
#  batch_normalization_5 (Batc  (64, 137, 16)            64
#  hNormalization)
#
#  pool3 (MaxPooling1D)        (64, 69, 16)              0
#
#  conv3 (Conv1D)              (64, 69, 32)              1568
#
#  leaky_re_lu_6 (LeakyReLU)   (64, 69, 32)              0
#
#  batch_normalization_6 (Batc  (64, 69, 32)             128
#  hNormalization)
#
#  pool4 (MaxPooling1D)        (64, 35, 32)              0
#
#  flatten (Flatten)           (64, 1120)                0
#
#  drop1 (Dropout)             (64, 1120)                0
#
#  dens1 (Dense)               (64, 1250)                1401250
#
#  drop2 (Dropout)             (64, 1250)                0
#
#  dens2 (Dense)               (64, 1500)                1876500
#
#  reshape_1 (Reshape)         (64, 5, 5, 60)            0
#
#  conv2d_transpose_3 (Conv2DT  (64, 10, 10, 8)          4320
#  ranspose)
#
#  leaky_re_lu_7 (LeakyReLU)   (64, 10, 10, 8)           0
#
#  batch_normalization_7 (Batc  (64, 10, 10, 8)          32
#  hNormalization)
#
#  conv2d_transpose_4 (Conv2DT  (64, 20, 20, 1)          200
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (64, 40, 40, 1)          25
#  ranspose)
#
#  conv2d_1 (Conv2D)           (64, 40, 40, 1)           25
#
# =================================================================
# Total params: 3,285,184
# Trainable params: 3,285,056
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# ## Visual comparison

# %%
def ResCompareProfiles(model, x, y, save_figures=False):
    index = 0
    counter = 0
    while index != -1:
        counter +=1
        clear_output()
        plt.set_cmap('cividis')

        prediction = mirror(model.predict(np.expand_dims(x[index], 0)).reshape((40, 40)))
        print(prediction.shape)
        truth = mirror(y[index].reshape((40, 40)))

        


        fig, ax = plt.subplots(1, 3, figsize=(11, 5))

        ax[0].fill_between(np.arange(0, 40), 0, prediction[40, :], color=colors[0], alpha=0.1)

        im_true = ax[0].plot(truth[40, :], label='Ground truth', linestyle='--', c='orange')
        ax[0].set_xlabel('Position along major axis', fontsize=14)
        ax[0].set_ylabel(r'$n_e/n_{crit}$', fontsize=16)

        ax[0].plot(prediction[40, :], label='Prediction', c=colors[0])
        ax[0].set_xlim((0, 39))
        ax[0].set_ylim((0, .6))
        ax[0].legend(loc='upper left', fontsize=9)
        ax[0].tick_params(axis='both', which='major', labelsize=12)
        
        #true = ax[1].imshow(norm_true, vmax=255, vmin=(min_value*255).astype(int))
        true = ax[1].contourf(truth, vmax=0.5, vmin=0, levels=200)
        ax[1].contour(truth, levels=np.arange(0.05, 1, .05), colors='black', linewidths=.7)
        ax[1].set_title('True profile', fontsize=14)
        ax[1].tick_params(axis='both', which='major', labelsize=12)
        #ax[2].imshow(norm_pred, vmax=255, vmin=(min_value*255).astype(int))
        ax[2].contourf(prediction, vmax=0.5, vmin=0, levels=200)
        ax[2].contour(prediction, levels=np.arange(0.05, 1, .05), colors='black', linewidths=.7)
        #ax[2].imshow(prediction, vmax=0.8, vmin=0)
        ax[2].set_title('Predicted profile', fontsize=14)
        ax[2].tick_params(axis='both', which='major', labelsize=12)

        fig.subplots_adjust(right=0.8)
        cbar_ax = fig.add_axes([0.83, 0.13, 0.02, 0.725]) # [left, bottom, width, height] 
        #//make the cbar_ax above be abit closer to the ax[2] figure

        norm = matplotlib.colors.Normalize(vmin=0, vmax=.5)
        cbar = fig.colorbar(matplotlib.cm.ScalarMappable(norm=norm, cmap='cividis'), cax=cbar_ax)
        cbar.ax.tick_params(labelsize=12)
        if save_figures:
            plt.savefig(f'04_files/figures/compare/{counter}.png', dpi=300)
        


        plt.show()

        index = int(input(f"Select new index, -1 to stop: "))

    return

# %%
ResCompareProfiles(nrmse_result, x_test, y_test_new, save_figures=False)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# (80, 40)

# %%
import os

os.system("ffmpeg  -r 1/1.5 -i ./04_files/figures/compare/%d.png -vb 20M -vcodec mpeg4 -y ./04_files/figures/compare/profiles.mp4")
# Out:
# 0

# %% [markdown]
# # Full comparison

# %%
predictions_split = optimised_result.predict(x_test)
predictions_ssim = ssim_result.predict(x_test)
predictions_nrmse = nrmse_result.predict(x_test)
# Out:
# 68/68 [==============================] - 1s 10ms/step
# 68/68 [==============================] - 1s 10ms/step
# 68/68 [==============================] - 1s 10ms/step

# %%
def get_peak(elem):
    return elem[0]

y_sorted = np.array([[peak.astype(np.float64), resolved] for peak, resolved in sorted(zip(y_test[:, 0], y_test_new), key=get_peak)])
pred_split_sorted = np.array(sorted(zip(y_test[:, 0], predictions_split), key=get_peak)) #change back to resolved_a here later
pred_ssim_sorted = np.array(sorted(zip(y_test[:, 0], predictions_ssim), key=get_peak))
pred_nrmse_sorted = np.array(sorted(zip(y_test[:, 0], predictions_nrmse), key=get_peak))

densities = y_sorted[:, 0]

#densities = densities[:500]

MAE_split_sorted = np.array([mae(y_sorted[i, 1].reshape((40, 40, 1)), pred_split_sorted[i, 1]) for i in range(len(densities))])
MAE_ssim_sorted = np.array([mae(y_sorted[i, 1].reshape((40, 40, 1)), pred_ssim_sorted[i, 1]) for i in range(len(densities))])
MAE_nrmse_sorted = np.array([mae(y_sorted[i, 1].reshape((40, 40, 1)), pred_nrmse_sorted[i, 1]) for i in range(len(densities))])
# Out:
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\1417760312.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y_sorted = np.array([[peak.astype(np.float64), resolved] for peak, resolved in sorted(zip(y_test[:, 0], y_test_new), key=get_peak)])
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\1417760312.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pred_split_sorted = np.array(sorted(zip(y_test[:, 0], predictions_split), key=get_peak)) #change back to resolved_a here later
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\1417760312.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pred_ssim_sorted = np.array(sorted(zip(y_test[:, 0], predictions_ssim), key=get_peak))
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\1417760312.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pred_nrmse_sorted = np.array(sorted(zip(y_test[:, 0], predictions_nrmse), key=get_peak))

# %%
print(np.mean(MAE_split_sorted))
print(np.mean(MAE_ssim_sorted))
print(np.mean(MAE_nrmse_sorted))
# Out:
# 0.008080352395142652
# 0.0895838750230578
# 0.0086461885887453

# %%
fig, ax = plt.subplots()

ax.scatter(densities, MAE_nrmse_sorted, s=15, alpha=0.5, c='orange', label='Test set')
#ax.scatter(densities, MAE_split_sorted_parametric, s=4, c='indianred', label = 'Parametric')


mean_100_split = []
mean_100_ssim = []
mean_100_nrmse = []
stdev_100 = []

for i in range(0 , len(MAE_split_sorted), 100): 
    #// Also calculate the standard deviation of the 100 points
    mean_100_split_points = sum(MAE_split_sorted[i:i+100])/100  # Calculate mean of 10 points  
    mean_100_ssim_points = sum(MAE_ssim_sorted[i:i+100])/100  # Calculate mean of 10 points
    mean_100_nrmse_points = sum(MAE_nrmse_sorted[i:i+100])/100  # Calculate mean of 10 points

    med_100_split_points = np.median(MAE_split_sorted[i:i+100])  # Calculate mean of 10 points
    med_100_ssim_points = np.median(MAE_ssim_sorted[i:i+100])  # Calculate mean of 10 points
    med_100_nrmse_points = np.median(MAE_nrmse_sorted[i:i+100])  # Calculate mean of 10 points


    mean_100_split.append(med_100_split_points) # Append the values in the list  
    mean_100_ssim.append(med_100_ssim_points) # Append the values in the list
    mean_100_nrmse.append(med_100_nrmse_points) # Append the values in the list

    #change the lines above back to mean when you want to use mean instead of median

    variance_100 = sum(((MAE_split_sorted[i:i+100] - mean_100_split_points) ** 2)) / 100 
    stdev_100.append(variance_100**0.5)


     # Plot the line graph
ax.plot(densities[::100],mean_100_split, c=colors[0], linewidth=3, linestyle='-', label=r'NRMSE+SSIM loss')
#ax.plot(densities[::100],mean_100_ssim, c='red', linewidth=3, linestyle='--', label=r'SSIM loss')
ax.plot(densities[::100],mean_100_nrmse, c='green', linewidth=3, linestyle='--', label=r'NRMSE loss')

ax.fill_between(np.array(densities[::100], dtype=float), 0,
 np.array(mean_100_split, dtype=float) + np.array(stdev_100, dtype=float), color=colors[0], alpha=0.2, label=r'$2\sigma_{100}$ interval')
 # label=r'$\overline{MAE}_{100} + 2\sigma_{100}$'

ax.legend(loc='upper left', fontsize=13)
ax.set_ylim((0, .03))
ax.set_xlim((0.1, densities[::100][-1]))

#ax.set_yticks([0, 0.005, 0.01, 0.015, 0.02])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_title('Running average $\overline{MAE}_{100}$ of resolved models', fontsize=16)
ax.set_xlabel(r'Normalized peak density', fontsize=14)
ax.set_ylabel(r'MAE($n_e/n_{crit}$)', fontsize=16)


print(np.array(densities[::100], dtype=float).dtype)

plt.savefig('06_files/figures/Com_MAE_resolved.pdf', bbox_inches='tight')
# Out:
# float64

# %% [markdown]
# """----------------------------------"""

# %%
print(np.mean(mae(y_test_new.reshape((-1, 40, 40)), predictions_split.reshape((-1, 40, 40)))))
print(np.mean(mae(y_test_new.reshape((-1, 40, 40)), predictions_ssim.reshape((-1, 40, 40)))))
print(np.mean(mae(y_test_new.reshape((-1, 40, 40)), predictions_nrmse.reshape((-1, 40, 40)))))
# Out:
# tf.Tensor(0.008080352395142652, shape=(), dtype=float64)
# tf.Tensor(0.0895838750230578, shape=(), dtype=float64)
# tf.Tensor(0.008646188588745302, shape=(), dtype=float64)

# %%
print(np.mean(nrmse(y_test_new.reshape((-1, 40, 40)), predictions_split.reshape((-1, 40, 40)))))
print(np.mean(nrmse(y_test_new.reshape((-1, 40, 40)), predictions_ssim.reshape((-1, 40, 40)))))
print(np.mean(nrmse(y_test_new.reshape((-1, 40, 40)), predictions_nrmse.reshape((-1, 40, 40)))))
# Out:
# tf.Tensor(0.027075320951321424, shape=(), dtype=float64)
# tf.Tensor(0.23250780621058784, shape=(), dtype=float64)
# tf.Tensor(0.027896818132423572, shape=(), dtype=float64)

# %%
print(np.mean(ssim_loss(y_test_new.reshape((-1, 40, 40)), predictions_split.reshape((-1, 40, 40)))))
print(np.mean(ssim_loss(y_test_new.reshape((-1, 40, 40)), predictions_ssim.reshape((-1, 40, 40)))))
print(np.mean(ssim_loss(y_test_new.reshape((-1, 40, 40)), predictions_nrmse.reshape((-1, 40, 40)))))
# Out:
# C:\Users\ewout\AppData\Local\Temp\ipykernel_154360\1319621768.py:33: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   return  ssim(y_true, y_pred, multichannel=True)
# c:\Users\ewout\anaconda3\lib\site-packages\skimage\_shared\utils.py:348: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)
# 0.9666554467417274
# 0.41372774627662545
# 0.9609572839482547

# %%
print(np.mean(psnr(y_test_new.reshape((-1, 40, 40)), predictions_split.reshape((-1, 40, 40)))))
print(np.mean(psnr(y_test_new.reshape((-1, 40, 40)), predictions_ssim.reshape((-1, 40, 40)))))
print(np.mean(psnr(y_test_new.reshape((-1, 40, 40)), predictions_nrmse.reshape((-1, 40, 40)))))
# Out:
# tf.Tensor(31.34852729542769, shape=(), dtype=float64)
# tf.Tensor(12.671249054806513, shape=(), dtype=float64)
# tf.Tensor(31.08890614533764, shape=(), dtype=float64)
